# %% [markdown]
# # First, set up the training images

# %% [markdown]
# ## Import data
# Replace `<path_to_data>` with the path to where you placed the NPY training files.

# %%
path = <path_to_data>

# %%
import numpy as np
import pandas as pd
X = np.load(path+'X.npy')
y = np.load(path+'y.npy')
file = np.load(path+'file.npy')

# set numpy seed for model
np.random.seed(0) # for reproducibility

# %%
# convert to grayscale
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

X = rgb2gray(X)
# Reshape to match CNN model requirements
X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)

# %% [markdown]
# # Define CNN model

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Convolutional Neural Network https://machinelearningmastery.com/keras-functional-api-deep-learning/

# Convolutional Neural Network
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D, AveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, AveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Sequential


input_shape = (X.shape[1], X.shape[2], X.shape[3])

nClasses = 2

def createModel():
    model = Sequential()
    model.add(Conv2D(16, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(16, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(nClasses, activation='sigmoid'))
    
    return model

# %%
######### train test split ###############
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn import preprocessing
from keras.utils import to_categorical
from sklearn.utils import class_weight
# set up k-fold cross-val
skf = StratifiedKFold(n_splits=5)
skf.get_n_splits(X, y)
for in1, in2 in skf.split(X, y):
  print(len(in1))
# Out:
# 5346
# 5346
# 5346
# 5347
# 5347

# %% [markdown]
# # Define MLP model

# %%
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier

# define and fit scaler
scaler = preprocessing.StandardScaler()


################## define and run model itself, after you've found good params ########
mlp = MLPClassifier(hidden_layer_sizes= (100, 50),
                    activation = 'relu',
                    solver = 'lbfgs',
                    alpha = 1e-5,
                    learning_rate = 'constant',
                    random_state = 0, max_iter=5000)

pipe = Pipeline(steps =[('scaler',scaler) , ('MLPClassifier', mlp)])

# %% [markdown]
# # Split train/test with k-fold

# %%
######### train test split ###############
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn import preprocessing
from keras.utils import to_categorical
from sklearn.utils import class_weight
from imblearn.over_sampling import SMOTE


# set up k-fold cross-val
skf = StratifiedKFold(n_splits=5)
skf.get_n_splits(X, y)

######################
# Set training process params, class weights (get class weights from the train/test split, below)
batch_size = 64
epochs = 80

number_models= 5

###################
# construct metrics
metrics = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
]
###################


# full list of models and histories
models=list()
histories=list()
histories_all = list()

# outcomes divided by fold
y_test_byfold = list()
y_train_byfold = list()
X_test_byfold = list()
X_train_byfold = list()
file_test_byfold = list()
file_train_byfold = list()
file_val_byfold = list()

# lists for CNN models
histories_byfold = list()
models_byfold = list()

# list for MLP models
pipes_byfold = list()
#####################
# construct "fold" counter to save data
fold = 0

for train_index, test_index in skf.split(X, y):
    print(fold)

    # reset model and history counter
    models = list()
    histories = list()

    # split data
    X1, X_test = X[train_index], X[test_index]
    y1, y_test = y[train_index], y[test_index]
    file1, file_test = file[train_index], file[test_index]

    # construct validation set
    X_train, X_val, y_train, y_val, file_train, file_val = train_test_split(X1, y1, file1, stratify = y1, test_size=0.15, random_state=0)
    
    # append all data to lists, to save for later
    y_train_byfold.append(y_train)
    y_test_byfold.append(y_test)

    X_test_byfold.append(X_test)
    X_train_byfold.append(X_train)

    file_test_byfold.append(file_test)
    file_train_byfold.append(file_train)
    file_val_byfold.append(file_val)


##################### ##################### ##################### 
    # MLP model
##################### ##################### ##################### 

   # resample training data
    over = SMOTE(sampling_strategy = .1)
    under = RandomUnderSampler(sampling_strategy=1)
    X_train_mlp, y_train_mlp = over.fit_resample(X_train, y_train)
    X_train_mlp, y_train_mlp = under.fit_resample(X_train, y_train)

    for i in range(0,5):
        pipe.fit(X_train, y_train)
        pipes.append(pipe)
    pipes_byfold.append(pipes)

##################### ##################### ##################### 
    # CNN MODEL
##################### ##################### ##################### 

    # compute class weights an assign to variable for model below
    class_weights = class_weight.compute_class_weight('balanced', np.unique(y_train),y_train)
    weight = {0: class_weights[0], 1: class_weights[1]}
    print(weight)

    # scale Xs and convert Ys to categorical
    X_train, X_val, X_test = X_train/255, X_val/255, X_test/255
    y_train, y_val, y_test = to_categorical(y_train), to_categorical(y_val), to_categorical(y_test)



    # run ensemble CNN model for each kfold
    for i in range(0,number_models):
      print(i)
      model = createModel()
      model.compile(optimizer='adamax', loss=keras.losses.BinaryCrossentropy(), metrics=metrics)
      history = model.fit(X_train, y_train,
                          batch_size=batch_size, 
                          epochs=epochs, verbose=1, class_weight = weight,
                          validation_data = (X_val, y_val),
                          # callbacks=[early_stopping], # this stops the training when the metric listed in model.compile has stopped improving
                          shuffle=False)
      
      # append to revolving models and histories list, in order to later append to full list of models and history
      models.append(model)
      histories.append(history.history)
      # append all histories for each model in each fold, to plot later
      histories_all.append(history.history)

    histories_byfold.append(histories)
    models_byfold.append(models)

    # iterate "fold" counter plus one
    
    fold = fold + 1
# Out:
# 0
# {0: 0.5264133456904542, 1: 9.964912280701755}
# 0
# Epoch 1/80
# 71/71 [==============================] - 5s 38ms/step - loss: 0.6778 - tp: 2121.1111 - fp: 321.4583 - tn: 2013.6528 - fn: 214.0000 - accuracy: 0.8762 - precision: 0.8528 - recall: 0.9199 - auc: 0.9234 - val_loss: 0.3282 - val_tp: 669.0000 - val_fp: 136.0000 - val_tn: 666.0000 - val_fn: 133.0000 - val_accuracy: 0.8323 - val_precision: 0.8311 - val_recall: 0.8342 - val_auc: 0.9318
# Epoch 2/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.5115 - tp: 1539.6250 - fp: 794.0694 - tn: 1541.0417 - fn: 795.4861 - accuracy: 0.6667 - precision: 0.6665 - recall: 0.6671 - auc: 0.8005 - val_loss: 0.3205 - val_tp: 669.0000 - val_fp: 131.0000 - val_tn: 671.0000 - val_fn: 133.0000 - val_accuracy: 0.8354 - val_precision: 0.8363 - val_recall: 0.8342 - val_auc: 0.9313
# Epoch 3/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.5039 - tp: 1566.8611 - fp: 766.1944 - tn: 1568.9167 - fn: 768.2500 - accuracy: 0.6835 - precision: 0.6834 - recall: 0.6834 - auc: 0.8104 - val_loss: 0.3005 - val_tp: 679.0000 - val_fp: 121.0000 - val_tn: 681.0000 - val_fn: 123.0000 - val_accuracy: 0.8479 - val_precision: 0.8487 - val_recall: 0.8466 - val_auc: 0.9415
# Epoch 4/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.5001 - tp: 1580.3194 - fp: 749.0556 - tn: 1586.0556 - fn: 754.7917 - accuracy: 0.6912 - precision: 0.6916 - recall: 0.6902 - auc: 0.8173 - val_loss: 0.3028 - val_tp: 679.0000 - val_fp: 126.0000 - val_tn: 676.0000 - val_fn: 123.0000 - val_accuracy: 0.8448 - val_precision: 0.8435 - val_recall: 0.8466 - val_auc: 0.9401
# Epoch 5/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4980 - tp: 1597.8889 - fp: 737.4306 - tn: 1597.6806 - fn: 737.2222 - accuracy: 0.6973 - precision: 0.6974 - recall: 0.6971 - auc: 0.8221 - val_loss: 0.2946 - val_tp: 682.0000 - val_fp: 120.0000 - val_tn: 682.0000 - val_fn: 120.0000 - val_accuracy: 0.8504 - val_precision: 0.8504 - val_recall: 0.8504 - val_auc: 0.9439
# Epoch 6/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4913 - tp: 1614.4028 - fp: 712.9861 - tn: 1622.1250 - fn: 720.7083 - accuracy: 0.7052 - precision: 0.7058 - recall: 0.7036 - auc: 0.8285 - val_loss: 0.2854 - val_tp: 687.0000 - val_fp: 111.0000 - val_tn: 691.0000 - val_fn: 115.0000 - val_accuracy: 0.8591 - val_precision: 0.8609 - val_recall: 0.8566 - val_auc: 0.9482
# Epoch 7/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4821 - tp: 1645.3333 - fp: 688.1944 - tn: 1646.9167 - fn: 689.7778 - accuracy: 0.7157 - precision: 0.7157 - recall: 0.7156 - auc: 0.8359 - val_loss: 0.2753 - val_tp: 696.0000 - val_fp: 105.0000 - val_tn: 697.0000 - val_fn: 106.0000 - val_accuracy: 0.8685 - val_precision: 0.8689 - val_recall: 0.8678 - val_auc: 0.9525
# Epoch 8/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4706 - tp: 1672.3056 - fp: 657.5556 - tn: 1677.5556 - fn: 662.8056 - accuracy: 0.7255 - precision: 0.7261 - recall: 0.7242 - auc: 0.8442 - val_loss: 0.2726 - val_tp: 698.0000 - val_fp: 105.0000 - val_tn: 697.0000 - val_fn: 104.0000 - val_accuracy: 0.8697 - val_precision: 0.8692 - val_recall: 0.8703 - val_auc: 0.9537
# Epoch 9/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4607 - tp: 1698.9583 - fp: 630.5417 - tn: 1704.5694 - fn: 636.1528 - accuracy: 0.7356 - precision: 0.7363 - recall: 0.7341 - auc: 0.8509 - val_loss: 0.2711 - val_tp: 697.0000 - val_fp: 106.0000 - val_tn: 696.0000 - val_fn: 105.0000 - val_accuracy: 0.8685 - val_precision: 0.8680 - val_recall: 0.8691 - val_auc: 0.9545
# Epoch 10/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.4529 - tp: 1718.5556 - fp: 618.9444 - tn: 1716.1667 - fn: 616.5556 - accuracy: 0.7437 - precision: 0.7432 - recall: 0.7448 - auc: 0.8561 - val_loss: 0.2688 - val_tp: 695.0000 - val_fp: 101.0000 - val_tn: 701.0000 - val_fn: 107.0000 - val_accuracy: 0.8703 - val_precision: 0.8731 - val_recall: 0.8666 - val_auc: 0.9553
# Epoch 11/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4467 - tp: 1725.7222 - fp: 610.7639 - tn: 1724.3472 - fn: 609.3889 - accuracy: 0.7463 - precision: 0.7457 - recall: 0.7472 - auc: 0.8613 - val_loss: 0.2672 - val_tp: 694.0000 - val_fp: 104.0000 - val_tn: 698.0000 - val_fn: 108.0000 - val_accuracy: 0.8678 - val_precision: 0.8697 - val_recall: 0.8653 - val_auc: 0.9557
# Epoch 12/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4412 - tp: 1739.5694 - fp: 596.0000 - tn: 1739.1111 - fn: 595.5417 - accuracy: 0.7522 - precision: 0.7522 - recall: 0.7524 - auc: 0.8656 - val_loss: 0.2654 - val_tp: 697.0000 - val_fp: 105.0000 - val_tn: 697.0000 - val_fn: 105.0000 - val_accuracy: 0.8691 - val_precision: 0.8691 - val_recall: 0.8691 - val_auc: 0.9563
# Epoch 13/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4363 - tp: 1751.0000 - fp: 587.7778 - tn: 1747.3333 - fn: 584.1111 - accuracy: 0.7566 - precision: 0.7560 - recall: 0.7578 - auc: 0.8695 - val_loss: 0.2633 - val_tp: 701.0000 - val_fp: 103.0000 - val_tn: 699.0000 - val_fn: 101.0000 - val_accuracy: 0.8728 - val_precision: 0.8719 - val_recall: 0.8741 - val_auc: 0.9571
# Epoch 14/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.4313 - tp: 1758.0556 - fp: 576.4583 - tn: 1758.6528 - fn: 577.0556 - accuracy: 0.7598 - precision: 0.7597 - recall: 0.7600 - auc: 0.8730 - val_loss: 0.2634 - val_tp: 700.0000 - val_fp: 98.0000 - val_tn: 704.0000 - val_fn: 102.0000 - val_accuracy: 0.8753 - val_precision: 0.8772 - val_recall: 0.8728 - val_auc: 0.9569
# Epoch 15/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.4268 - tp: 1768.0278 - fp: 568.1944 - tn: 1766.9167 - fn: 567.0833 - accuracy: 0.7633 - precision: 0.7632 - recall: 0.7635 - auc: 0.8761 - val_loss: 0.2637 - val_tp: 701.0000 - val_fp: 97.0000 - val_tn: 705.0000 - val_fn: 101.0000 - val_accuracy: 0.8766 - val_precision: 0.8784 - val_recall: 0.8741 - val_auc: 0.9567
# Epoch 16/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.4217 - tp: 1776.0972 - fp: 561.3194 - tn: 1773.7917 - fn: 559.0139 - accuracy: 0.7668 - precision: 0.7661 - recall: 0.7680 - auc: 0.8786 - val_loss: 0.2589 - val_tp: 703.0000 - val_fp: 97.0000 - val_tn: 705.0000 - val_fn: 99.0000 - val_accuracy: 0.8778 - val_precision: 0.8788 - val_recall: 0.8766 - val_auc: 0.9585
# Epoch 17/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4177 - tp: 1781.9444 - fp: 549.7222 - tn: 1785.3889 - fn: 553.1667 - accuracy: 0.7704 - precision: 0.7705 - recall: 0.7700 - auc: 0.8820 - val_loss: 0.2593 - val_tp: 704.0000 - val_fp: 97.0000 - val_tn: 705.0000 - val_fn: 98.0000 - val_accuracy: 0.8784 - val_precision: 0.8789 - val_recall: 0.8778 - val_auc: 0.9584
# Epoch 18/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4128 - tp: 1786.0694 - fp: 544.6528 - tn: 1790.4583 - fn: 549.0417 - accuracy: 0.7720 - precision: 0.7723 - recall: 0.7713 - auc: 0.8841 - val_loss: 0.2593 - val_tp: 705.0000 - val_fp: 99.0000 - val_tn: 703.0000 - val_fn: 97.0000 - val_accuracy: 0.8778 - val_precision: 0.8769 - val_recall: 0.8791 - val_auc: 0.9583
# Epoch 19/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4087 - tp: 1791.7500 - fp: 539.7500 - tn: 1795.3611 - fn: 543.3611 - accuracy: 0.7744 - precision: 0.7747 - recall: 0.7739 - auc: 0.8863 - val_loss: 0.2548 - val_tp: 706.0000 - val_fp: 96.0000 - val_tn: 706.0000 - val_fn: 96.0000 - val_accuracy: 0.8803 - val_precision: 0.8803 - val_recall: 0.8803 - val_auc: 0.9599
# Epoch 20/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4040 - tp: 1800.2500 - fp: 532.4167 - tn: 1802.6944 - fn: 534.8611 - accuracy: 0.7786 - precision: 0.7787 - recall: 0.7782 - auc: 0.8889 - val_loss: 0.2557 - val_tp: 704.0000 - val_fp: 99.0000 - val_tn: 703.0000 - val_fn: 98.0000 - val_accuracy: 0.8772 - val_precision: 0.8767 - val_recall: 0.8778 - val_auc: 0.9595
# Epoch 21/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4001 - tp: 1804.2361 - fp: 525.8472 - tn: 1809.2639 - fn: 530.8750 - accuracy: 0.7809 - precision: 0.7812 - recall: 0.7803 - auc: 0.8907 - val_loss: 0.2523 - val_tp: 707.0000 - val_fp: 97.0000 - val_tn: 705.0000 - val_fn: 95.0000 - val_accuracy: 0.8803 - val_precision: 0.8794 - val_recall: 0.8815 - val_auc: 0.9606
# Epoch 22/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3958 - tp: 1810.0278 - fp: 522.4444 - tn: 1812.6667 - fn: 525.0833 - accuracy: 0.7833 - precision: 0.7835 - recall: 0.7829 - auc: 0.8933 - val_loss: 0.2535 - val_tp: 704.0000 - val_fp: 98.0000 - val_tn: 704.0000 - val_fn: 98.0000 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9601
# Epoch 23/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3919 - tp: 1817.9444 - fp: 515.5833 - tn: 1819.5278 - fn: 517.1667 - accuracy: 0.7865 - precision: 0.7866 - recall: 0.7863 - auc: 0.8951 - val_loss: 0.2497 - val_tp: 705.0000 - val_fp: 96.0000 - val_tn: 706.0000 - val_fn: 97.0000 - val_accuracy: 0.8797 - val_precision: 0.8801 - val_recall: 0.8791 - val_auc: 0.9613
# Epoch 24/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3877 - tp: 1824.5556 - fp: 508.8333 - tn: 1826.2778 - fn: 510.5556 - accuracy: 0.7899 - precision: 0.7902 - recall: 0.7896 - auc: 0.8974 - val_loss: 0.2487 - val_tp: 705.0000 - val_fp: 95.0000 - val_tn: 707.0000 - val_fn: 97.0000 - val_accuracy: 0.8803 - val_precision: 0.8813 - val_recall: 0.8791 - val_auc: 0.9616
# Epoch 25/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3834 - tp: 1827.2083 - fp: 503.8472 - tn: 1831.2639 - fn: 507.9028 - accuracy: 0.7912 - precision: 0.7918 - recall: 0.7903 - auc: 0.8994 - val_loss: 0.2462 - val_tp: 707.0000 - val_fp: 93.0000 - val_tn: 709.0000 - val_fn: 95.0000 - val_accuracy: 0.8828 - val_precision: 0.8838 - val_recall: 0.8815 - val_auc: 0.9624
# Epoch 26/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3792 - tp: 1833.2917 - fp: 495.5694 - tn: 1839.5417 - fn: 501.8194 - accuracy: 0.7943 - precision: 0.7950 - recall: 0.7930 - auc: 0.9014 - val_loss: 0.2451 - val_tp: 708.0000 - val_fp: 93.0000 - val_tn: 709.0000 - val_fn: 94.0000 - val_accuracy: 0.8834 - val_precision: 0.8839 - val_recall: 0.8828 - val_auc: 0.9627
# Epoch 27/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3751 - tp: 1843.0833 - fp: 490.0694 - tn: 1845.0417 - fn: 492.0278 - accuracy: 0.7974 - precision: 0.7977 - recall: 0.7969 - auc: 0.9033 - val_loss: 0.2427 - val_tp: 709.0000 - val_fp: 90.0000 - val_tn: 712.0000 - val_fn: 93.0000 - val_accuracy: 0.8859 - val_precision: 0.8874 - val_recall: 0.8840 - val_auc: 0.9634
# Epoch 28/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3711 - tp: 1851.8889 - fp: 483.5556 - tn: 1851.5556 - fn: 483.2222 - accuracy: 0.8009 - precision: 0.8008 - recall: 0.8010 - auc: 0.9053 - val_loss: 0.2408 - val_tp: 710.0000 - val_fp: 88.0000 - val_tn: 714.0000 - val_fn: 92.0000 - val_accuracy: 0.8878 - val_precision: 0.8897 - val_recall: 0.8853 - val_auc: 0.9640
# Epoch 29/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3671 - tp: 1857.2361 - fp: 476.1111 - tn: 1859.0000 - fn: 477.8750 - accuracy: 0.8037 - precision: 0.8040 - recall: 0.8033 - auc: 0.9072 - val_loss: 0.2393 - val_tp: 710.0000 - val_fp: 87.0000 - val_tn: 715.0000 - val_fn: 92.0000 - val_accuracy: 0.8884 - val_precision: 0.8908 - val_recall: 0.8853 - val_auc: 0.9644
# Epoch 30/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3633 - tp: 1864.8750 - fp: 468.7500 - tn: 1866.3611 - fn: 470.2361 - accuracy: 0.8072 - precision: 0.8072 - recall: 0.8070 - auc: 0.9092 - val_loss: 0.2354 - val_tp: 715.0000 - val_fp: 86.0000 - val_tn: 716.0000 - val_fn: 87.0000 - val_accuracy: 0.8921 - val_precision: 0.8926 - val_recall: 0.8915 - val_auc: 0.9656
# Epoch 31/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3587 - tp: 1872.5139 - fp: 462.6111 - tn: 1872.5000 - fn: 462.5972 - accuracy: 0.8108 - precision: 0.8107 - recall: 0.8109 - auc: 0.9113 - val_loss: 0.2342 - val_tp: 716.0000 - val_fp: 85.0000 - val_tn: 717.0000 - val_fn: 86.0000 - val_accuracy: 0.8934 - val_precision: 0.8939 - val_recall: 0.8928 - val_auc: 0.9660
# Epoch 32/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3547 - tp: 1874.6111 - fp: 455.9028 - tn: 1879.2083 - fn: 460.5000 - accuracy: 0.8126 - precision: 0.8133 - recall: 0.8116 - auc: 0.9130 - val_loss: 0.2305 - val_tp: 717.0000 - val_fp: 83.0000 - val_tn: 719.0000 - val_fn: 85.0000 - val_accuracy: 0.8953 - val_precision: 0.8963 - val_recall: 0.8940 - val_auc: 0.9672
# Epoch 33/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3496 - tp: 1884.6528 - fp: 447.1944 - tn: 1887.9167 - fn: 450.4583 - accuracy: 0.8163 - precision: 0.8167 - recall: 0.8157 - auc: 0.9152 - val_loss: 0.2289 - val_tp: 718.0000 - val_fp: 81.0000 - val_tn: 721.0000 - val_fn: 84.0000 - val_accuracy: 0.8971 - val_precision: 0.8986 - val_recall: 0.8953 - val_auc: 0.9676
# Epoch 34/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3455 - tp: 1893.6111 - fp: 434.3194 - tn: 1900.7917 - fn: 441.5000 - accuracy: 0.8217 - precision: 0.8228 - recall: 0.8200 - auc: 0.9172 - val_loss: 0.2257 - val_tp: 720.0000 - val_fp: 81.0000 - val_tn: 721.0000 - val_fn: 82.0000 - val_accuracy: 0.8984 - val_precision: 0.8989 - val_recall: 0.8978 - val_auc: 0.9685
# Epoch 35/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3406 - tp: 1900.1528 - fp: 424.5556 - tn: 1910.5556 - fn: 434.9583 - accuracy: 0.8252 - precision: 0.8270 - recall: 0.8225 - auc: 0.9194 - val_loss: 0.2243 - val_tp: 721.0000 - val_fp: 79.0000 - val_tn: 723.0000 - val_fn: 81.0000 - val_accuracy: 0.9002 - val_precision: 0.9013 - val_recall: 0.8990 - val_auc: 0.9689
# Epoch 36/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3366 - tp: 1908.1389 - fp: 416.8611 - tn: 1918.2500 - fn: 426.9722 - accuracy: 0.8284 - precision: 0.8297 - recall: 0.8263 - auc: 0.9213 - val_loss: 0.2202 - val_tp: 722.0000 - val_fp: 76.0000 - val_tn: 726.0000 - val_fn: 80.0000 - val_accuracy: 0.9027 - val_precision: 0.9048 - val_recall: 0.9002 - val_auc: 0.9701
# Epoch 37/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.3317 - tp: 1913.5139 - fp: 414.4167 - tn: 1920.6944 - fn: 421.5972 - accuracy: 0.8300 - precision: 0.8312 - recall: 0.8283 - auc: 0.9234 - val_loss: 0.2173 - val_tp: 722.0000 - val_fp: 76.0000 - val_tn: 726.0000 - val_fn: 80.0000 - val_accuracy: 0.9027 - val_precision: 0.9048 - val_recall: 0.9002 - val_auc: 0.9709
# Epoch 38/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3273 - tp: 1917.7500 - fp: 411.4167 - tn: 1923.6944 - fn: 417.3611 - accuracy: 0.8316 - precision: 0.8326 - recall: 0.8302 - auc: 0.9254 - val_loss: 0.2137 - val_tp: 725.0000 - val_fp: 73.0000 - val_tn: 729.0000 - val_fn: 77.0000 - val_accuracy: 0.9065 - val_precision: 0.9085 - val_recall: 0.9040 - val_auc: 0.9719
# Epoch 39/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3219 - tp: 1929.8194 - fp: 405.1250 - tn: 1929.9861 - fn: 405.2917 - accuracy: 0.8356 - precision: 0.8353 - recall: 0.8360 - auc: 0.9274 - val_loss: 0.2113 - val_tp: 724.0000 - val_fp: 73.0000 - val_tn: 729.0000 - val_fn: 78.0000 - val_accuracy: 0.9059 - val_precision: 0.9084 - val_recall: 0.9027 - val_auc: 0.9726
# Epoch 40/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3172 - tp: 1933.8472 - fp: 397.4167 - tn: 1937.6944 - fn: 401.2639 - accuracy: 0.8382 - precision: 0.8385 - recall: 0.8377 - auc: 0.9294 - val_loss: 0.2086 - val_tp: 726.0000 - val_fp: 74.0000 - val_tn: 728.0000 - val_fn: 76.0000 - val_accuracy: 0.9065 - val_precision: 0.9075 - val_recall: 0.9052 - val_auc: 0.9732
# Epoch 41/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3122 - tp: 1940.3750 - fp: 392.8472 - tn: 1942.2639 - fn: 394.7361 - accuracy: 0.8403 - precision: 0.8402 - recall: 0.8404 - auc: 0.9314 - val_loss: 0.2061 - val_tp: 726.0000 - val_fp: 72.0000 - val_tn: 730.0000 - val_fn: 76.0000 - val_accuracy: 0.9077 - val_precision: 0.9098 - val_recall: 0.9052 - val_auc: 0.9739
# Epoch 42/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3076 - tp: 1943.6250 - fp: 386.6944 - tn: 1948.4167 - fn: 391.4861 - accuracy: 0.8425 - precision: 0.8431 - recall: 0.8417 - auc: 0.9335 - val_loss: 0.2030 - val_tp: 728.0000 - val_fp: 71.0000 - val_tn: 731.0000 - val_fn: 74.0000 - val_accuracy: 0.9096 - val_precision: 0.9111 - val_recall: 0.9077 - val_auc: 0.9747
# Epoch 43/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3027 - tp: 1948.6389 - fp: 380.3472 - tn: 1954.7639 - fn: 386.4722 - accuracy: 0.8443 - precision: 0.8451 - recall: 0.8431 - auc: 0.9353 - val_loss: 0.2007 - val_tp: 730.0000 - val_fp: 72.0000 - val_tn: 730.0000 - val_fn: 72.0000 - val_accuracy: 0.9102 - val_precision: 0.9102 - val_recall: 0.9102 - val_auc: 0.9753
# Epoch 44/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2985 - tp: 1954.3611 - fp: 374.4444 - tn: 1960.6667 - fn: 380.7500 - accuracy: 0.8469 - precision: 0.8473 - recall: 0.8461 - auc: 0.9369 - val_loss: 0.1990 - val_tp: 731.0000 - val_fp: 71.0000 - val_tn: 731.0000 - val_fn: 71.0000 - val_accuracy: 0.9115 - val_precision: 0.9115 - val_recall: 0.9115 - val_auc: 0.9758
# Epoch 45/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2941 - tp: 1960.4583 - fp: 365.6944 - tn: 1969.4167 - fn: 374.6528 - accuracy: 0.8499 - precision: 0.8512 - recall: 0.8480 - auc: 0.9387 - val_loss: 0.1981 - val_tp: 730.0000 - val_fp: 71.0000 - val_tn: 731.0000 - val_fn: 72.0000 - val_accuracy: 0.9108 - val_precision: 0.9114 - val_recall: 0.9102 - val_auc: 0.9760
# Epoch 46/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2902 - tp: 1965.5556 - fp: 362.1944 - tn: 1972.9167 - fn: 369.5556 - accuracy: 0.8515 - precision: 0.8522 - recall: 0.8506 - auc: 0.9403 - val_loss: 0.1944 - val_tp: 734.0000 - val_fp: 68.0000 - val_tn: 734.0000 - val_fn: 68.0000 - val_accuracy: 0.9152 - val_precision: 0.9152 - val_recall: 0.9152 - val_auc: 0.9769
# Epoch 47/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2845 - tp: 1972.6667 - fp: 360.0417 - tn: 1975.0694 - fn: 362.4444 - accuracy: 0.8535 - precision: 0.8538 - recall: 0.8531 - auc: 0.9418 - val_loss: 0.1918 - val_tp: 735.0000 - val_fp: 67.0000 - val_tn: 735.0000 - val_fn: 67.0000 - val_accuracy: 0.9165 - val_precision: 0.9165 - val_recall: 0.9165 - val_auc: 0.9776
# Epoch 48/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2803 - tp: 1976.2917 - fp: 354.8889 - tn: 1980.2222 - fn: 358.8194 - accuracy: 0.8552 - precision: 0.8556 - recall: 0.8547 - auc: 0.9438 - val_loss: 0.1905 - val_tp: 735.0000 - val_fp: 66.0000 - val_tn: 736.0000 - val_fn: 67.0000 - val_accuracy: 0.9171 - val_precision: 0.9176 - val_recall: 0.9165 - val_auc: 0.9778
# Epoch 49/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2764 - tp: 1985.7778 - fp: 348.0694 - tn: 1987.0417 - fn: 349.3333 - accuracy: 0.8586 - precision: 0.8587 - recall: 0.8585 - auc: 0.9454 - val_loss: 0.1890 - val_tp: 735.0000 - val_fp: 66.0000 - val_tn: 736.0000 - val_fn: 67.0000 - val_accuracy: 0.9171 - val_precision: 0.9176 - val_recall: 0.9165 - val_auc: 0.9783
# Epoch 50/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2710 - tp: 1991.3056 - fp: 346.6111 - tn: 1988.5000 - fn: 343.8056 - accuracy: 0.8594 - precision: 0.8586 - recall: 0.8604 - auc: 0.9466 - val_loss: 0.1856 - val_tp: 734.0000 - val_fp: 64.0000 - val_tn: 738.0000 - val_fn: 68.0000 - val_accuracy: 0.9177 - val_precision: 0.9198 - val_recall: 0.9152 - val_auc: 0.9791
# Epoch 51/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2673 - tp: 1997.3750 - fp: 333.9722 - tn: 2001.1389 - fn: 337.7361 - accuracy: 0.8635 - precision: 0.8641 - recall: 0.8628 - auc: 0.9488 - val_loss: 0.1867 - val_tp: 736.0000 - val_fp: 66.0000 - val_tn: 736.0000 - val_fn: 66.0000 - val_accuracy: 0.9177 - val_precision: 0.9177 - val_recall: 0.9177 - val_auc: 0.9789
# Epoch 52/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2630 - tp: 2006.2222 - fp: 323.6806 - tn: 2011.4306 - fn: 328.8889 - accuracy: 0.8678 - precision: 0.8685 - recall: 0.8667 - auc: 0.9499 - val_loss: 0.1845 - val_tp: 734.0000 - val_fp: 64.0000 - val_tn: 738.0000 - val_fn: 68.0000 - val_accuracy: 0.9177 - val_precision: 0.9198 - val_recall: 0.9152 - val_auc: 0.9794
# Epoch 53/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2582 - tp: 2014.4861 - fp: 312.0139 - tn: 2023.0972 - fn: 320.6250 - accuracy: 0.8724 - precision: 0.8738 - recall: 0.8706 - auc: 0.9517 - val_loss: 0.1846 - val_tp: 735.0000 - val_fp: 66.0000 - val_tn: 736.0000 - val_fn: 67.0000 - val_accuracy: 0.9171 - val_precision: 0.9176 - val_recall: 0.9165 - val_auc: 0.9793
# Epoch 54/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2556 - tp: 2019.1667 - fp: 313.9167 - tn: 2021.1944 - fn: 315.9444 - accuracy: 0.8728 - precision: 0.8729 - recall: 0.8726 - auc: 0.9527 - val_loss: 0.1830 - val_tp: 736.0000 - val_fp: 65.0000 - val_tn: 737.0000 - val_fn: 66.0000 - val_accuracy: 0.9183 - val_precision: 0.9189 - val_recall: 0.9177 - val_auc: 0.9796
# Epoch 55/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2480 - tp: 2026.7500 - fp: 303.3194 - tn: 2031.7917 - fn: 308.3611 - accuracy: 0.8758 - precision: 0.8765 - recall: 0.8749 - auc: 0.9545 - val_loss: 0.1816 - val_tp: 736.0000 - val_fp: 65.0000 - val_tn: 737.0000 - val_fn: 66.0000 - val_accuracy: 0.9183 - val_precision: 0.9189 - val_recall: 0.9177 - val_auc: 0.9800
# Epoch 56/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2435 - tp: 2031.6806 - fp: 300.3056 - tn: 2034.8056 - fn: 303.4306 - accuracy: 0.8769 - precision: 0.8774 - recall: 0.8764 - auc: 0.9559 - val_loss: 0.1784 - val_tp: 737.0000 - val_fp: 64.0000 - val_tn: 738.0000 - val_fn: 65.0000 - val_accuracy: 0.9196 - val_precision: 0.9201 - val_recall: 0.9190 - val_auc: 0.9809
# Epoch 57/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2388 - tp: 2035.9167 - fp: 292.7083 - tn: 2042.4028 - fn: 299.1944 - accuracy: 0.8789 - precision: 0.8798 - recall: 0.8777 - auc: 0.9573 - val_loss: 0.1774 - val_tp: 738.0000 - val_fp: 64.0000 - val_tn: 738.0000 - val_fn: 64.0000 - val_accuracy: 0.9202 - val_precision: 0.9202 - val_recall: 0.9202 - val_auc: 0.9812
# Epoch 58/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2338 - tp: 2038.6944 - fp: 288.5694 - tn: 2046.5417 - fn: 296.4167 - accuracy: 0.8805 - precision: 0.8818 - recall: 0.8789 - auc: 0.9582 - val_loss: 0.1755 - val_tp: 739.0000 - val_fp: 61.0000 - val_tn: 741.0000 - val_fn: 63.0000 - val_accuracy: 0.9227 - val_precision: 0.9237 - val_recall: 0.9214 - val_auc: 0.9816
# Epoch 59/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2287 - tp: 2049.9722 - fp: 279.7500 - tn: 2055.3611 - fn: 285.1389 - accuracy: 0.8843 - precision: 0.8851 - recall: 0.8833 - auc: 0.9599 - val_loss: 0.1732 - val_tp: 741.0000 - val_fp: 59.0000 - val_tn: 743.0000 - val_fn: 61.0000 - val_accuracy: 0.9252 - val_precision: 0.9262 - val_recall: 0.9239 - val_auc: 0.9822
# Epoch 60/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2237 - tp: 2056.4722 - fp: 275.4306 - tn: 2059.6806 - fn: 278.6389 - accuracy: 0.8864 - precision: 0.8867 - recall: 0.8860 - auc: 0.9613 - val_loss: 0.1736 - val_tp: 741.0000 - val_fp: 60.0000 - val_tn: 742.0000 - val_fn: 61.0000 - val_accuracy: 0.9246 - val_precision: 0.9251 - val_recall: 0.9239 - val_auc: 0.9820
# Epoch 61/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2184 - tp: 2062.0417 - fp: 266.6250 - tn: 2068.4861 - fn: 273.0694 - accuracy: 0.8891 - precision: 0.8901 - recall: 0.8878 - auc: 0.9626 - val_loss: 0.1700 - val_tp: 741.0000 - val_fp: 56.0000 - val_tn: 746.0000 - val_fn: 61.0000 - val_accuracy: 0.9271 - val_precision: 0.9297 - val_recall: 0.9239 - val_auc: 0.9825
# Epoch 62/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2148 - tp: 2068.4444 - fp: 262.5000 - tn: 2072.6111 - fn: 266.6667 - accuracy: 0.8905 - precision: 0.8910 - recall: 0.8898 - auc: 0.9640 - val_loss: 0.1733 - val_tp: 741.0000 - val_fp: 58.0000 - val_tn: 744.0000 - val_fn: 61.0000 - val_accuracy: 0.9258 - val_precision: 0.9274 - val_recall: 0.9239 - val_auc: 0.9816
# Epoch 63/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2097 - tp: 2071.4306 - fp: 259.1389 - tn: 2075.9722 - fn: 263.6806 - accuracy: 0.8921 - precision: 0.8930 - recall: 0.8910 - auc: 0.9650 - val_loss: 0.1691 - val_tp: 743.0000 - val_fp: 54.0000 - val_tn: 748.0000 - val_fn: 59.0000 - val_accuracy: 0.9296 - val_precision: 0.9322 - val_recall: 0.9264 - val_auc: 0.9826
# Epoch 64/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2066 - tp: 2077.2778 - fp: 254.2639 - tn: 2080.8472 - fn: 257.8333 - accuracy: 0.8939 - precision: 0.8945 - recall: 0.8932 - auc: 0.9666 - val_loss: 0.1705 - val_tp: 744.0000 - val_fp: 56.0000 - val_tn: 746.0000 - val_fn: 58.0000 - val_accuracy: 0.9289 - val_precision: 0.9300 - val_recall: 0.9277 - val_auc: 0.9826
# Epoch 65/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2004 - tp: 2081.3472 - fp: 250.2639 - tn: 2084.8472 - fn: 253.7639 - accuracy: 0.8954 - precision: 0.8960 - recall: 0.8946 - auc: 0.9678 - val_loss: 0.1675 - val_tp: 748.0000 - val_fp: 52.0000 - val_tn: 750.0000 - val_fn: 54.0000 - val_accuracy: 0.9339 - val_precision: 0.9350 - val_recall: 0.9327 - val_auc: 0.9833
# Epoch 66/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1967 - tp: 2089.7917 - fp: 242.1944 - tn: 2092.9167 - fn: 245.3194 - accuracy: 0.8986 - precision: 0.8990 - recall: 0.8981 - auc: 0.9693 - val_loss: 0.1666 - val_tp: 749.0000 - val_fp: 51.0000 - val_tn: 751.0000 - val_fn: 53.0000 - val_accuracy: 0.9352 - val_precision: 0.9362 - val_recall: 0.9339 - val_auc: 0.9837
# Epoch 67/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1917 - tp: 2098.7917 - fp: 234.5278 - tn: 2100.5833 - fn: 236.3194 - accuracy: 0.9018 - precision: 0.9021 - recall: 0.9014 - auc: 0.9708 - val_loss: 0.1661 - val_tp: 749.0000 - val_fp: 52.0000 - val_tn: 750.0000 - val_fn: 53.0000 - val_accuracy: 0.9345 - val_precision: 0.9351 - val_recall: 0.9339 - val_auc: 0.9839
# Epoch 68/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1881 - tp: 2105.2639 - fp: 229.0278 - tn: 2106.0833 - fn: 229.8472 - accuracy: 0.9042 - precision: 0.9044 - recall: 0.9039 - auc: 0.9719 - val_loss: 0.1671 - val_tp: 751.0000 - val_fp: 53.0000 - val_tn: 749.0000 - val_fn: 51.0000 - val_accuracy: 0.9352 - val_precision: 0.9341 - val_recall: 0.9364 - val_auc: 0.9836
# Epoch 69/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1836 - tp: 2110.6528 - fp: 221.5972 - tn: 2113.5139 - fn: 224.4583 - accuracy: 0.9070 - precision: 0.9077 - recall: 0.9061 - auc: 0.9730 - val_loss: 0.1654 - val_tp: 750.0000 - val_fp: 53.0000 - val_tn: 749.0000 - val_fn: 52.0000 - val_accuracy: 0.9345 - val_precision: 0.9340 - val_recall: 0.9352 - val_auc: 0.9841
# Epoch 70/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1800 - tp: 2121.4167 - fp: 214.3333 - tn: 2120.7778 - fn: 213.6944 - accuracy: 0.9105 - precision: 0.9103 - recall: 0.9107 - auc: 0.9739 - val_loss: 0.1624 - val_tp: 754.0000 - val_fp: 49.0000 - val_tn: 753.0000 - val_fn: 48.0000 - val_accuracy: 0.9395 - val_precision: 0.9390 - val_recall: 0.9401 - val_auc: 0.9848
# Epoch 71/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1751 - tp: 2125.9444 - fp: 208.1111 - tn: 2127.0000 - fn: 209.1667 - accuracy: 0.9126 - precision: 0.9129 - recall: 0.9123 - auc: 0.9759 - val_loss: 0.1615 - val_tp: 756.0000 - val_fp: 46.0000 - val_tn: 756.0000 - val_fn: 46.0000 - val_accuracy: 0.9426 - val_precision: 0.9426 - val_recall: 0.9426 - val_auc: 0.9841
# Epoch 72/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1708 - tp: 2135.8750 - fp: 199.7917 - tn: 2135.3194 - fn: 199.2361 - accuracy: 0.9170 - precision: 0.9163 - recall: 0.9178 - auc: 0.9773 - val_loss: 0.1619 - val_tp: 755.0000 - val_fp: 46.0000 - val_tn: 756.0000 - val_fn: 47.0000 - val_accuracy: 0.9420 - val_precision: 0.9426 - val_recall: 0.9414 - val_auc: 0.9841
# Epoch 73/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1670 - tp: 2135.8333 - fp: 197.5972 - tn: 2137.5139 - fn: 199.2778 - accuracy: 0.9167 - precision: 0.9168 - recall: 0.9165 - auc: 0.9778 - val_loss: 0.1609 - val_tp: 756.0000 - val_fp: 45.0000 - val_tn: 757.0000 - val_fn: 46.0000 - val_accuracy: 0.9433 - val_precision: 0.9438 - val_recall: 0.9426 - val_auc: 0.9844
# Epoch 74/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1643 - tp: 2135.8472 - fp: 199.3056 - tn: 2135.8056 - fn: 199.2639 - accuracy: 0.9160 - precision: 0.9159 - recall: 0.9162 - auc: 0.9782 - val_loss: 0.1628 - val_tp: 759.0000 - val_fp: 42.0000 - val_tn: 760.0000 - val_fn: 43.0000 - val_accuracy: 0.9470 - val_precision: 0.9476 - val_recall: 0.9464 - val_auc: 0.9836
# Epoch 75/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1606 - tp: 2144.7917 - fp: 188.2222 - tn: 2146.8889 - fn: 190.3194 - accuracy: 0.9209 - precision: 0.9212 - recall: 0.9205 - auc: 0.9799 - val_loss: 0.1607 - val_tp: 759.0000 - val_fp: 42.0000 - val_tn: 760.0000 - val_fn: 43.0000 - val_accuracy: 0.9470 - val_precision: 0.9476 - val_recall: 0.9464 - val_auc: 0.9840
# Epoch 76/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1564 - tp: 2150.7222 - fp: 178.6528 - tn: 2156.4583 - fn: 184.3889 - accuracy: 0.9234 - precision: 0.9244 - recall: 0.9223 - auc: 0.9807 - val_loss: 0.1636 - val_tp: 759.0000 - val_fp: 44.0000 - val_tn: 758.0000 - val_fn: 43.0000 - val_accuracy: 0.9458 - val_precision: 0.9452 - val_recall: 0.9464 - val_auc: 0.9835
# Epoch 77/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1519 - tp: 2158.5972 - fp: 175.5556 - tn: 2159.5556 - fn: 176.5139 - accuracy: 0.9258 - precision: 0.9257 - recall: 0.9260 - auc: 0.9816 - val_loss: 0.1620 - val_tp: 763.0000 - val_fp: 39.0000 - val_tn: 763.0000 - val_fn: 39.0000 - val_accuracy: 0.9514 - val_precision: 0.9514 - val_recall: 0.9514 - val_auc: 0.9843
# Epoch 78/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1488 - tp: 2158.8056 - fp: 175.7639 - tn: 2159.3472 - fn: 176.3056 - accuracy: 0.9251 - precision: 0.9252 - recall: 0.9250 - auc: 0.9820 - val_loss: 0.1624 - val_tp: 762.0000 - val_fp: 39.0000 - val_tn: 763.0000 - val_fn: 40.0000 - val_accuracy: 0.9507 - val_precision: 0.9513 - val_recall: 0.9501 - val_auc: 0.9845
# Epoch 79/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1452 - tp: 2163.4583 - fp: 170.7639 - tn: 2164.3472 - fn: 171.6528 - accuracy: 0.9270 - precision: 0.9272 - recall: 0.9269 - auc: 0.9829 - val_loss: 0.1623 - val_tp: 765.0000 - val_fp: 37.0000 - val_tn: 765.0000 - val_fn: 37.0000 - val_accuracy: 0.9539 - val_precision: 0.9539 - val_recall: 0.9539 - val_auc: 0.9843
# Epoch 80/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.1415 - tp: 2165.0694 - fp: 168.1111 - tn: 2167.0000 - fn: 170.0417 - accuracy: 0.9281 - precision: 0.9281 - recall: 0.9280 - auc: 0.9836 - val_loss: 0.1639 - val_tp: 764.0000 - val_fp: 37.0000 - val_tn: 765.0000 - val_fn: 38.0000 - val_accuracy: 0.9532 - val_precision: 0.9538 - val_recall: 0.9526 - val_auc: 0.9841
# 1
# Epoch 1/80
# 71/71 [==============================] - 4s 36ms/step - loss: 0.6774 - tp: 2735.9583 - fp: 421.3333 - tn: 2715.7778 - fn: 401.1528 - accuracy: 0.8788 - precision: 0.8733 - recall: 0.8857 - auc: 0.9430 - val_loss: 0.3490 - val_tp: 655.0000 - val_fp: 139.0000 - val_tn: 663.0000 - val_fn: 147.0000 - val_accuracy: 0.8217 - val_precision: 0.8249 - val_recall: 0.8167 - val_auc: 0.9225
# Epoch 2/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4933 - tp: 1592.7917 - fp: 747.5833 - tn: 1587.5278 - fn: 742.3194 - accuracy: 0.6884 - precision: 0.6880 - recall: 0.6893 - auc: 0.8106 - val_loss: 0.3467 - val_tp: 651.0000 - val_fp: 149.0000 - val_tn: 653.0000 - val_fn: 151.0000 - val_accuracy: 0.8130 - val_precision: 0.8138 - val_recall: 0.8117 - val_auc: 0.9179
# Epoch 3/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4907 - tp: 1628.5972 - fp: 710.3750 - tn: 1624.7361 - fn: 706.5139 - accuracy: 0.7042 - precision: 0.7038 - recall: 0.7051 - auc: 0.8245 - val_loss: 0.3122 - val_tp: 672.0000 - val_fp: 126.0000 - val_tn: 676.0000 - val_fn: 130.0000 - val_accuracy: 0.8404 - val_precision: 0.8421 - val_recall: 0.8379 - val_auc: 0.9365
# Epoch 4/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4774 - tp: 1639.2083 - fp: 687.7917 - tn: 1647.3194 - fn: 695.9028 - accuracy: 0.7104 - precision: 0.7110 - recall: 0.7088 - auc: 0.8313 - val_loss: 0.3028 - val_tp: 677.0000 - val_fp: 125.0000 - val_tn: 677.0000 - val_fn: 125.0000 - val_accuracy: 0.8441 - val_precision: 0.8441 - val_recall: 0.8441 - val_auc: 0.9410
# Epoch 5/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4721 - tp: 1650.4861 - fp: 677.4722 - tn: 1657.6389 - fn: 684.6250 - accuracy: 0.7149 - precision: 0.7156 - recall: 0.7135 - auc: 0.8377 - val_loss: 0.3056 - val_tp: 673.0000 - val_fp: 125.0000 - val_tn: 677.0000 - val_fn: 129.0000 - val_accuracy: 0.8416 - val_precision: 0.8434 - val_recall: 0.8392 - val_auc: 0.9399
# Epoch 6/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4657 - tp: 1663.0278 - fp: 670.9444 - tn: 1664.1667 - fn: 672.0833 - accuracy: 0.7177 - precision: 0.7178 - recall: 0.7175 - auc: 0.8415 - val_loss: 0.3042 - val_tp: 676.0000 - val_fp: 125.0000 - val_tn: 677.0000 - val_fn: 126.0000 - val_accuracy: 0.8435 - val_precision: 0.8439 - val_recall: 0.8429 - val_auc: 0.9408
# Epoch 7/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4602 - tp: 1673.5000 - fp: 656.9583 - tn: 1678.1528 - fn: 661.6111 - accuracy: 0.7221 - precision: 0.7227 - recall: 0.7209 - auc: 0.8459 - val_loss: 0.3024 - val_tp: 681.0000 - val_fp: 123.0000 - val_tn: 679.0000 - val_fn: 121.0000 - val_accuracy: 0.8479 - val_precision: 0.8470 - val_recall: 0.8491 - val_auc: 0.9416
# Epoch 8/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4545 - tp: 1686.7778 - fp: 642.6528 - tn: 1692.4583 - fn: 648.3333 - accuracy: 0.7281 - precision: 0.7287 - recall: 0.7268 - auc: 0.8503 - val_loss: 0.2999 - val_tp: 682.0000 - val_fp: 120.0000 - val_tn: 682.0000 - val_fn: 120.0000 - val_accuracy: 0.8504 - val_precision: 0.8504 - val_recall: 0.8504 - val_auc: 0.9427
# Epoch 9/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4489 - tp: 1699.0417 - fp: 634.6528 - tn: 1700.4583 - fn: 636.0694 - accuracy: 0.7324 - precision: 0.7324 - recall: 0.7323 - auc: 0.8545 - val_loss: 0.2966 - val_tp: 682.0000 - val_fp: 117.0000 - val_tn: 685.0000 - val_fn: 120.0000 - val_accuracy: 0.8522 - val_precision: 0.8536 - val_recall: 0.8504 - val_auc: 0.9441
# Epoch 10/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4438 - tp: 1711.1944 - fp: 622.0972 - tn: 1713.0139 - fn: 623.9167 - accuracy: 0.7376 - precision: 0.7379 - recall: 0.7371 - auc: 0.8580 - val_loss: 0.2928 - val_tp: 682.0000 - val_fp: 116.0000 - val_tn: 686.0000 - val_fn: 120.0000 - val_accuracy: 0.8529 - val_precision: 0.8546 - val_recall: 0.8504 - val_auc: 0.9457
# Epoch 11/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4394 - tp: 1723.2500 - fp: 614.2083 - tn: 1720.9028 - fn: 611.8611 - accuracy: 0.7419 - precision: 0.7417 - recall: 0.7424 - auc: 0.8616 - val_loss: 0.2887 - val_tp: 687.0000 - val_fp: 112.0000 - val_tn: 690.0000 - val_fn: 115.0000 - val_accuracy: 0.8585 - val_precision: 0.8598 - val_recall: 0.8566 - val_auc: 0.9473
# Epoch 12/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.4347 - tp: 1732.6806 - fp: 602.6944 - tn: 1732.4167 - fn: 602.4306 - accuracy: 0.7470 - precision: 0.7470 - recall: 0.7470 - auc: 0.8651 - val_loss: 0.2851 - val_tp: 686.0000 - val_fp: 111.0000 - val_tn: 691.0000 - val_fn: 116.0000 - val_accuracy: 0.8585 - val_precision: 0.8607 - val_recall: 0.8554 - val_auc: 0.9487
# Epoch 13/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4302 - tp: 1735.1250 - fp: 595.4028 - tn: 1739.7083 - fn: 599.9861 - accuracy: 0.7479 - precision: 0.7484 - recall: 0.7468 - auc: 0.8685 - val_loss: 0.2806 - val_tp: 693.0000 - val_fp: 106.0000 - val_tn: 696.0000 - val_fn: 109.0000 - val_accuracy: 0.8660 - val_precision: 0.8673 - val_recall: 0.8641 - val_auc: 0.9505
# Epoch 14/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4256 - tp: 1752.3194 - fp: 588.7639 - tn: 1746.3472 - fn: 582.7917 - accuracy: 0.7533 - precision: 0.7526 - recall: 0.7546 - auc: 0.8716 - val_loss: 0.2764 - val_tp: 697.0000 - val_fp: 102.0000 - val_tn: 700.0000 - val_fn: 105.0000 - val_accuracy: 0.8709 - val_precision: 0.8723 - val_recall: 0.8691 - val_auc: 0.9521
# Epoch 15/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4214 - tp: 1765.5972 - fp: 572.7361 - tn: 1762.3750 - fn: 569.5139 - accuracy: 0.7604 - precision: 0.7602 - recall: 0.7610 - auc: 0.8749 - val_loss: 0.2745 - val_tp: 697.0000 - val_fp: 103.0000 - val_tn: 699.0000 - val_fn: 105.0000 - val_accuracy: 0.8703 - val_precision: 0.8712 - val_recall: 0.8691 - val_auc: 0.9528
# Epoch 16/80
# 71/71 [==============================] - 5s 65ms/step - loss: 0.4171 - tp: 1770.6389 - fp: 565.8333 - tn: 1769.2778 - fn: 564.4722 - accuracy: 0.7639 - precision: 0.7637 - recall: 0.7644 - auc: 0.8776 - val_loss: 0.2713 - val_tp: 699.0000 - val_fp: 101.0000 - val_tn: 701.0000 - val_fn: 103.0000 - val_accuracy: 0.8728 - val_precision: 0.8737 - val_recall: 0.8716 - val_auc: 0.9541
# Epoch 17/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.4127 - tp: 1771.7917 - fp: 557.1111 - tn: 1778.0000 - fn: 563.3194 - accuracy: 0.7659 - precision: 0.7669 - recall: 0.7642 - auc: 0.8801 - val_loss: 0.2678 - val_tp: 701.0000 - val_fp: 100.0000 - val_tn: 702.0000 - val_fn: 101.0000 - val_accuracy: 0.8747 - val_precision: 0.8752 - val_recall: 0.8741 - val_auc: 0.9553
# Epoch 18/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4080 - tp: 1786.9167 - fp: 541.9028 - tn: 1793.2083 - fn: 548.1944 - accuracy: 0.7736 - precision: 0.7746 - recall: 0.7720 - auc: 0.8830 - val_loss: 0.2658 - val_tp: 703.0000 - val_fp: 96.0000 - val_tn: 706.0000 - val_fn: 99.0000 - val_accuracy: 0.8784 - val_precision: 0.8798 - val_recall: 0.8766 - val_auc: 0.9559
# Epoch 19/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.4036 - tp: 1797.9167 - fp: 535.3611 - tn: 1799.7500 - fn: 537.1944 - accuracy: 0.7777 - precision: 0.7781 - recall: 0.7772 - auc: 0.8856 - val_loss: 0.2615 - val_tp: 706.0000 - val_fp: 94.0000 - val_tn: 708.0000 - val_fn: 96.0000 - val_accuracy: 0.8815 - val_precision: 0.8825 - val_recall: 0.8803 - val_auc: 0.9574
# Epoch 20/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3991 - tp: 1809.7500 - fp: 526.5556 - tn: 1808.5556 - fn: 525.3611 - accuracy: 0.7824 - precision: 0.7820 - recall: 0.7830 - auc: 0.8884 - val_loss: 0.2601 - val_tp: 707.0000 - val_fp: 94.0000 - val_tn: 708.0000 - val_fn: 95.0000 - val_accuracy: 0.8822 - val_precision: 0.8826 - val_recall: 0.8815 - val_auc: 0.9579
# Epoch 21/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.3947 - tp: 1818.3750 - fp: 517.5833 - tn: 1817.5278 - fn: 516.7361 - accuracy: 0.7863 - precision: 0.7863 - recall: 0.7865 - auc: 0.8907 - val_loss: 0.2563 - val_tp: 708.0000 - val_fp: 91.0000 - val_tn: 711.0000 - val_fn: 94.0000 - val_accuracy: 0.8847 - val_precision: 0.8861 - val_recall: 0.8828 - val_auc: 0.9592
# Epoch 22/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3898 - tp: 1827.4722 - fp: 512.2917 - tn: 1822.8194 - fn: 507.6389 - accuracy: 0.7891 - precision: 0.7884 - recall: 0.7902 - auc: 0.8933 - val_loss: 0.2529 - val_tp: 712.0000 - val_fp: 90.0000 - val_tn: 712.0000 - val_fn: 90.0000 - val_accuracy: 0.8878 - val_precision: 0.8878 - val_recall: 0.8878 - val_auc: 0.9604
# Epoch 23/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3857 - tp: 1836.4722 - fp: 503.8750 - tn: 1831.2361 - fn: 498.6389 - accuracy: 0.7929 - precision: 0.7919 - recall: 0.7945 - auc: 0.8959 - val_loss: 0.2510 - val_tp: 713.0000 - val_fp: 89.0000 - val_tn: 713.0000 - val_fn: 89.0000 - val_accuracy: 0.8890 - val_precision: 0.8890 - val_recall: 0.8890 - val_auc: 0.9609
# Epoch 24/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3806 - tp: 1844.3889 - fp: 495.2917 - tn: 1839.8194 - fn: 490.7222 - accuracy: 0.7972 - precision: 0.7960 - recall: 0.7991 - auc: 0.8987 - val_loss: 0.2482 - val_tp: 714.0000 - val_fp: 87.0000 - val_tn: 715.0000 - val_fn: 88.0000 - val_accuracy: 0.8909 - val_precision: 0.8914 - val_recall: 0.8903 - val_auc: 0.9619
# Epoch 25/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3756 - tp: 1852.4167 - fp: 487.5000 - tn: 1847.6111 - fn: 482.6944 - accuracy: 0.8007 - precision: 0.7990 - recall: 0.8034 - auc: 0.9010 - val_loss: 0.2450 - val_tp: 715.0000 - val_fp: 86.0000 - val_tn: 716.0000 - val_fn: 87.0000 - val_accuracy: 0.8921 - val_precision: 0.8926 - val_recall: 0.8915 - val_auc: 0.9629
# Epoch 26/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.3703 - tp: 1863.1944 - fp: 476.2639 - tn: 1858.8472 - fn: 471.9167 - accuracy: 0.8056 - precision: 0.8045 - recall: 0.8073 - auc: 0.9037 - val_loss: 0.2429 - val_tp: 714.0000 - val_fp: 87.0000 - val_tn: 715.0000 - val_fn: 88.0000 - val_accuracy: 0.8909 - val_precision: 0.8914 - val_recall: 0.8903 - val_auc: 0.9636
# Epoch 27/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3663 - tp: 1867.5972 - fp: 471.6389 - tn: 1863.4722 - fn: 467.5139 - accuracy: 0.8072 - precision: 0.8065 - recall: 0.8084 - auc: 0.9062 - val_loss: 0.2386 - val_tp: 716.0000 - val_fp: 84.0000 - val_tn: 718.0000 - val_fn: 86.0000 - val_accuracy: 0.8940 - val_precision: 0.8950 - val_recall: 0.8928 - val_auc: 0.9649
# Epoch 28/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.3607 - tp: 1875.3611 - fp: 458.6250 - tn: 1876.4861 - fn: 459.7500 - accuracy: 0.8121 - precision: 0.8129 - recall: 0.8111 - auc: 0.9090 - val_loss: 0.2355 - val_tp: 718.0000 - val_fp: 84.0000 - val_tn: 718.0000 - val_fn: 84.0000 - val_accuracy: 0.8953 - val_precision: 0.8953 - val_recall: 0.8953 - val_auc: 0.9659
# Epoch 29/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.3560 - tp: 1883.0694 - fp: 451.5000 - tn: 1883.6111 - fn: 452.0417 - accuracy: 0.8150 - precision: 0.8158 - recall: 0.8141 - auc: 0.9119 - val_loss: 0.2321 - val_tp: 720.0000 - val_fp: 84.0000 - val_tn: 718.0000 - val_fn: 82.0000 - val_accuracy: 0.8965 - val_precision: 0.8955 - val_recall: 0.8978 - val_auc: 0.9670
# Epoch 30/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.3505 - tp: 1895.9028 - fp: 444.7917 - tn: 1890.3194 - fn: 439.2083 - accuracy: 0.8195 - precision: 0.8189 - recall: 0.8205 - auc: 0.9145 - val_loss: 0.2289 - val_tp: 721.0000 - val_fp: 83.0000 - val_tn: 719.0000 - val_fn: 81.0000 - val_accuracy: 0.8978 - val_precision: 0.8968 - val_recall: 0.8990 - val_auc: 0.9679
# Epoch 31/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.3457 - tp: 1902.8056 - fp: 434.0278 - tn: 1901.0833 - fn: 432.3056 - accuracy: 0.8240 - precision: 0.8238 - recall: 0.8243 - auc: 0.9173 - val_loss: 0.2263 - val_tp: 723.0000 - val_fp: 81.0000 - val_tn: 721.0000 - val_fn: 79.0000 - val_accuracy: 0.9002 - val_precision: 0.8993 - val_recall: 0.9015 - val_auc: 0.9687
# Epoch 32/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.3399 - tp: 1911.9861 - fp: 427.5000 - tn: 1907.6111 - fn: 423.1250 - accuracy: 0.8276 - precision: 0.8268 - recall: 0.8288 - auc: 0.9199 - val_loss: 0.2215 - val_tp: 726.0000 - val_fp: 77.0000 - val_tn: 725.0000 - val_fn: 76.0000 - val_accuracy: 0.9046 - val_precision: 0.9041 - val_recall: 0.9052 - val_auc: 0.9700
# Epoch 33/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.3336 - tp: 1920.0000 - fp: 413.2083 - tn: 1921.9028 - fn: 415.1111 - accuracy: 0.8324 - precision: 0.8325 - recall: 0.8323 - auc: 0.9227 - val_loss: 0.2179 - val_tp: 728.0000 - val_fp: 75.0000 - val_tn: 727.0000 - val_fn: 74.0000 - val_accuracy: 0.9071 - val_precision: 0.9066 - val_recall: 0.9077 - val_auc: 0.9710
# Epoch 34/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3272 - tp: 1928.1806 - fp: 409.1806 - tn: 1925.9306 - fn: 406.9306 - accuracy: 0.8346 - precision: 0.8346 - recall: 0.8347 - auc: 0.9255 - val_loss: 0.2150 - val_tp: 729.0000 - val_fp: 72.0000 - val_tn: 730.0000 - val_fn: 73.0000 - val_accuracy: 0.9096 - val_precision: 0.9101 - val_recall: 0.9090 - val_auc: 0.9717
# Epoch 35/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3208 - tp: 1934.6528 - fp: 399.4167 - tn: 1935.6944 - fn: 400.4583 - accuracy: 0.8381 - precision: 0.8384 - recall: 0.8378 - auc: 0.9282 - val_loss: 0.2123 - val_tp: 730.0000 - val_fp: 70.0000 - val_tn: 732.0000 - val_fn: 72.0000 - val_accuracy: 0.9115 - val_precision: 0.9125 - val_recall: 0.9102 - val_auc: 0.9723
# Epoch 36/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.3148 - tp: 1943.2222 - fp: 392.9167 - tn: 1942.1944 - fn: 391.8889 - accuracy: 0.8418 - precision: 0.8416 - recall: 0.8421 - auc: 0.9309 - val_loss: 0.2107 - val_tp: 732.0000 - val_fp: 67.0000 - val_tn: 735.0000 - val_fn: 70.0000 - val_accuracy: 0.9146 - val_precision: 0.9161 - val_recall: 0.9127 - val_auc: 0.9728
# Epoch 37/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3090 - tp: 1951.9167 - fp: 384.3750 - tn: 1950.7361 - fn: 383.1944 - accuracy: 0.8451 - precision: 0.8446 - recall: 0.8458 - auc: 0.9333 - val_loss: 0.2095 - val_tp: 734.0000 - val_fp: 67.0000 - val_tn: 735.0000 - val_fn: 68.0000 - val_accuracy: 0.9158 - val_precision: 0.9164 - val_recall: 0.9152 - val_auc: 0.9732
# Epoch 38/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.3023 - tp: 1956.3056 - fp: 375.5972 - tn: 1959.5139 - fn: 378.8056 - accuracy: 0.8472 - precision: 0.8471 - recall: 0.8472 - auc: 0.9354 - val_loss: 0.2085 - val_tp: 734.0000 - val_fp: 69.0000 - val_tn: 733.0000 - val_fn: 68.0000 - val_accuracy: 0.9146 - val_precision: 0.9141 - val_recall: 0.9152 - val_auc: 0.9734
# Epoch 39/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2968 - tp: 1964.6944 - fp: 369.9306 - tn: 1965.1806 - fn: 370.4167 - accuracy: 0.8501 - precision: 0.8495 - recall: 0.8508 - auc: 0.9377 - val_loss: 0.2044 - val_tp: 735.0000 - val_fp: 68.0000 - val_tn: 734.0000 - val_fn: 67.0000 - val_accuracy: 0.9158 - val_precision: 0.9153 - val_recall: 0.9165 - val_auc: 0.9745
# Epoch 40/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2921 - tp: 1971.4722 - fp: 362.4306 - tn: 1972.6806 - fn: 363.6389 - accuracy: 0.8526 - precision: 0.8521 - recall: 0.8533 - auc: 0.9400 - val_loss: 0.2039 - val_tp: 734.0000 - val_fp: 68.0000 - val_tn: 734.0000 - val_fn: 68.0000 - val_accuracy: 0.9152 - val_precision: 0.9152 - val_recall: 0.9152 - val_auc: 0.9745
# Epoch 41/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.2858 - tp: 1989.1528 - fp: 356.9167 - tn: 1978.1944 - fn: 345.9583 - accuracy: 0.8571 - precision: 0.8551 - recall: 0.8600 - auc: 0.9421 - val_loss: 0.2037 - val_tp: 734.0000 - val_fp: 68.0000 - val_tn: 734.0000 - val_fn: 68.0000 - val_accuracy: 0.9152 - val_precision: 0.9152 - val_recall: 0.9152 - val_auc: 0.9746
# Epoch 42/80
# 71/71 [==============================] - 2s 25ms/step - loss: 0.2811 - tp: 1996.5139 - fp: 345.5556 - tn: 1989.5556 - fn: 338.5972 - accuracy: 0.8611 - precision: 0.8597 - recall: 0.8632 - auc: 0.9436 - val_loss: 0.1978 - val_tp: 736.0000 - val_fp: 65.0000 - val_tn: 737.0000 - val_fn: 66.0000 - val_accuracy: 0.9183 - val_precision: 0.9189 - val_recall: 0.9177 - val_auc: 0.9759
# Epoch 43/80
# ...
# Epoch 41/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2773 - tp: 1990.4444 - fp: 340.1111 - tn: 1995.0000 - fn: 344.6667 - accuracy: 0.8624 - precision: 0.8634 - recall: 0.8611 - auc: 0.9437 - val_loss: 0.2229 - val_tp: 724.0000 - val_fp: 80.0000 - val_tn: 723.0000 - val_fn: 79.0000 - val_accuracy: 0.9010 - val_precision: 0.9005 - val_recall: 0.9016 - val_auc: 0.9695
# Epoch 42/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2742 - tp: 1991.2639 - fp: 345.5000 - tn: 1989.6111 - fn: 343.8472 - accuracy: 0.8607 - precision: 0.8604 - recall: 0.8612 - auc: 0.9450 - val_loss: 0.2106 - val_tp: 731.0000 - val_fp: 73.0000 - val_tn: 730.0000 - val_fn: 72.0000 - val_accuracy: 0.9097 - val_precision: 0.9092 - val_recall: 0.9103 - val_auc: 0.9730
# Epoch 43/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2684 - tp: 2001.0694 - fp: 334.4028 - tn: 2000.7083 - fn: 334.0417 - accuracy: 0.8655 - precision: 0.8655 - recall: 0.8655 - auc: 0.9468 - val_loss: 0.2141 - val_tp: 729.0000 - val_fp: 76.0000 - val_tn: 727.0000 - val_fn: 74.0000 - val_accuracy: 0.9066 - val_precision: 0.9056 - val_recall: 0.9078 - val_auc: 0.9717
# Epoch 44/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2639 - tp: 2007.7222 - fp: 328.1667 - tn: 2006.9444 - fn: 327.3889 - accuracy: 0.8677 - precision: 0.8676 - recall: 0.8679 - auc: 0.9486 - val_loss: 0.2093 - val_tp: 731.0000 - val_fp: 74.0000 - val_tn: 729.0000 - val_fn: 72.0000 - val_accuracy: 0.9091 - val_precision: 0.9081 - val_recall: 0.9103 - val_auc: 0.9728
# Epoch 45/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2592 - tp: 2013.4167 - fp: 322.0417 - tn: 2013.0694 - fn: 321.6944 - accuracy: 0.8697 - precision: 0.8698 - recall: 0.8695 - auc: 0.9500 - val_loss: 0.2061 - val_tp: 733.0000 - val_fp: 72.0000 - val_tn: 731.0000 - val_fn: 70.0000 - val_accuracy: 0.9116 - val_precision: 0.9106 - val_recall: 0.9128 - val_auc: 0.9738
# Epoch 46/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2544 - tp: 2020.8750 - fp: 314.1528 - tn: 2020.9583 - fn: 314.2361 - accuracy: 0.8724 - precision: 0.8727 - recall: 0.8721 - auc: 0.9516 - val_loss: 0.2011 - val_tp: 737.0000 - val_fp: 66.0000 - val_tn: 737.0000 - val_fn: 66.0000 - val_accuracy: 0.9178 - val_precision: 0.9178 - val_recall: 0.9178 - val_auc: 0.9751
# Epoch 47/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2488 - tp: 2029.7778 - fp: 302.2639 - tn: 2032.8472 - fn: 305.3333 - accuracy: 0.8763 - precision: 0.8767 - recall: 0.8758 - auc: 0.9537 - val_loss: 0.1982 - val_tp: 737.0000 - val_fp: 66.0000 - val_tn: 737.0000 - val_fn: 66.0000 - val_accuracy: 0.9178 - val_precision: 0.9178 - val_recall: 0.9178 - val_auc: 0.9758
# Epoch 48/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2434 - tp: 2045.5972 - fp: 292.3750 - tn: 2042.7361 - fn: 289.5139 - accuracy: 0.8819 - precision: 0.8816 - recall: 0.8824 - auc: 0.9561 - val_loss: 0.1956 - val_tp: 739.0000 - val_fp: 64.0000 - val_tn: 739.0000 - val_fn: 64.0000 - val_accuracy: 0.9203 - val_precision: 0.9203 - val_recall: 0.9203 - val_auc: 0.9762
# Epoch 49/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2390 - tp: 2051.4583 - fp: 282.4167 - tn: 2052.6944 - fn: 283.6528 - accuracy: 0.8855 - precision: 0.8859 - recall: 0.8851 - auc: 0.9573 - val_loss: 0.1978 - val_tp: 740.0000 - val_fp: 66.0000 - val_tn: 737.0000 - val_fn: 63.0000 - val_accuracy: 0.9197 - val_precision: 0.9181 - val_recall: 0.9215 - val_auc: 0.9757
# Epoch 50/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2353 - tp: 2052.1806 - fp: 281.9861 - tn: 2053.1250 - fn: 282.9306 - accuracy: 0.8855 - precision: 0.8859 - recall: 0.8850 - auc: 0.9591 - val_loss: 0.1986 - val_tp: 738.0000 - val_fp: 63.0000 - val_tn: 740.0000 - val_fn: 65.0000 - val_accuracy: 0.9203 - val_precision: 0.9213 - val_recall: 0.9191 - val_auc: 0.9755
# Epoch 51/80
# 71/71 [==============================] - 2s 24ms/step - loss: 0.2299 - tp: 2056.1389 - fp: 275.7361 - tn: 2059.3750 - fn: 278.9722 - accuracy: 0.8871 - precision: 0.8877 - recall: 0.8864 - auc: 0.9597 - val_loss: 0.1955 - val_tp: 742.0000 - val_fp: 65.0000 - val_tn: 738.0000 - val_fn: 61.0000 - val_accuracy: 0.9215 - val_precision: 0.9195 - val_recall: 0.9240 - val_auc: 0.9760
# Epoch 52/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2253 - tp: 2063.2083 - fp: 271.8333 - tn: 2063.2778 - fn: 271.9028 - accuracy: 0.8904 - precision: 0.8903 - recall: 0.8904 - auc: 0.9618 - val_loss: 0.1973 - val_tp: 742.0000 - val_fp: 64.0000 - val_tn: 739.0000 - val_fn: 61.0000 - val_accuracy: 0.9222 - val_precision: 0.9206 - val_recall: 0.9240 - val_auc: 0.9757
# Epoch 53/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2208 - tp: 2069.0833 - fp: 267.0417 - tn: 2068.0694 - fn: 266.0278 - accuracy: 0.8923 - precision: 0.8920 - recall: 0.8927 - auc: 0.9628 - val_loss: 0.1918 - val_tp: 744.0000 - val_fp: 61.0000 - val_tn: 742.0000 - val_fn: 59.0000 - val_accuracy: 0.9253 - val_precision: 0.9242 - val_recall: 0.9265 - val_auc: 0.9771
# Epoch 54/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2155 - tp: 2077.3194 - fp: 259.5139 - tn: 2075.5972 - fn: 257.7917 - accuracy: 0.8955 - precision: 0.8951 - recall: 0.8959 - auc: 0.9645 - val_loss: 0.1908 - val_tp: 744.0000 - val_fp: 60.0000 - val_tn: 743.0000 - val_fn: 59.0000 - val_accuracy: 0.9259 - val_precision: 0.9254 - val_recall: 0.9265 - val_auc: 0.9774
# Epoch 55/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2106 - tp: 2083.3333 - fp: 249.9306 - tn: 2085.1806 - fn: 251.7778 - accuracy: 0.8986 - precision: 0.8987 - recall: 0.8984 - auc: 0.9659 - val_loss: 0.1851 - val_tp: 749.0000 - val_fp: 58.0000 - val_tn: 745.0000 - val_fn: 54.0000 - val_accuracy: 0.9303 - val_precision: 0.9281 - val_recall: 0.9328 - val_auc: 0.9787
# Epoch 56/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2059 - tp: 2094.0417 - fp: 246.9861 - tn: 2088.1250 - fn: 241.0694 - accuracy: 0.9013 - precision: 0.9000 - recall: 0.9029 - auc: 0.9674 - val_loss: 0.1827 - val_tp: 749.0000 - val_fp: 56.0000 - val_tn: 747.0000 - val_fn: 54.0000 - val_accuracy: 0.9315 - val_precision: 0.9304 - val_recall: 0.9328 - val_auc: 0.9793
# Epoch 57/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.2016 - tp: 2097.3056 - fp: 241.6944 - tn: 2093.4167 - fn: 237.8056 - accuracy: 0.9030 - precision: 0.9021 - recall: 0.9040 - auc: 0.9687 - val_loss: 0.1818 - val_tp: 748.0000 - val_fp: 55.0000 - val_tn: 748.0000 - val_fn: 55.0000 - val_accuracy: 0.9315 - val_precision: 0.9315 - val_recall: 0.9315 - val_auc: 0.9796
# Epoch 58/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1967 - tp: 2104.1806 - fp: 233.9444 - tn: 2101.1667 - fn: 230.9306 - accuracy: 0.9058 - precision: 0.9051 - recall: 0.9067 - auc: 0.9699 - val_loss: 0.1804 - val_tp: 750.0000 - val_fp: 52.0000 - val_tn: 751.0000 - val_fn: 53.0000 - val_accuracy: 0.9346 - val_precision: 0.9352 - val_recall: 0.9340 - val_auc: 0.9800
# Epoch 59/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1918 - tp: 2111.1667 - fp: 226.4583 - tn: 2108.6528 - fn: 223.9444 - accuracy: 0.9088 - precision: 0.9081 - recall: 0.9096 - auc: 0.9712 - val_loss: 0.1798 - val_tp: 751.0000 - val_fp: 50.0000 - val_tn: 753.0000 - val_fn: 52.0000 - val_accuracy: 0.9365 - val_precision: 0.9376 - val_recall: 0.9352 - val_auc: 0.9803
# Epoch 60/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1871 - tp: 2119.9722 - fp: 220.2778 - tn: 2114.8333 - fn: 215.1389 - accuracy: 0.9115 - precision: 0.9104 - recall: 0.9128 - auc: 0.9725 - val_loss: 0.1803 - val_tp: 751.0000 - val_fp: 50.0000 - val_tn: 753.0000 - val_fn: 52.0000 - val_accuracy: 0.9365 - val_precision: 0.9376 - val_recall: 0.9352 - val_auc: 0.9803
# Epoch 61/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1827 - tp: 2126.6111 - fp: 214.9861 - tn: 2120.1250 - fn: 208.5000 - accuracy: 0.9137 - precision: 0.9126 - recall: 0.9151 - auc: 0.9736 - val_loss: 0.1762 - val_tp: 754.0000 - val_fp: 49.0000 - val_tn: 754.0000 - val_fn: 49.0000 - val_accuracy: 0.9390 - val_precision: 0.9390 - val_recall: 0.9390 - val_auc: 0.9812
# Epoch 62/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1780 - tp: 2130.8194 - fp: 208.1806 - tn: 2126.9306 - fn: 204.2917 - accuracy: 0.9157 - precision: 0.9151 - recall: 0.9164 - auc: 0.9750 - val_loss: 0.1773 - val_tp: 754.0000 - val_fp: 49.0000 - val_tn: 754.0000 - val_fn: 49.0000 - val_accuracy: 0.9390 - val_precision: 0.9390 - val_recall: 0.9390 - val_auc: 0.9811
# Epoch 63/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1738 - tp: 2135.8611 - fp: 203.2778 - tn: 2131.8333 - fn: 199.2500 - accuracy: 0.9175 - precision: 0.9169 - recall: 0.9181 - auc: 0.9759 - val_loss: 0.1743 - val_tp: 755.0000 - val_fp: 47.0000 - val_tn: 756.0000 - val_fn: 48.0000 - val_accuracy: 0.9408 - val_precision: 0.9414 - val_recall: 0.9402 - val_auc: 0.9819
# Epoch 64/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1693 - tp: 2139.5833 - fp: 197.4722 - tn: 2137.6389 - fn: 195.5278 - accuracy: 0.9192 - precision: 0.9191 - recall: 0.9194 - auc: 0.9771 - val_loss: 0.1750 - val_tp: 755.0000 - val_fp: 47.0000 - val_tn: 756.0000 - val_fn: 48.0000 - val_accuracy: 0.9408 - val_precision: 0.9414 - val_recall: 0.9402 - val_auc: 0.9818
# Epoch 65/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1651 - tp: 2143.1250 - fp: 189.9028 - tn: 2145.2083 - fn: 191.9861 - accuracy: 0.9215 - precision: 0.9220 - recall: 0.9209 - auc: 0.9781 - val_loss: 0.1717 - val_tp: 757.0000 - val_fp: 45.0000 - val_tn: 758.0000 - val_fn: 46.0000 - val_accuracy: 0.9433 - val_precision: 0.9439 - val_recall: 0.9427 - val_auc: 0.9824
# Epoch 66/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1605 - tp: 2150.4028 - fp: 183.8333 - tn: 2151.2778 - fn: 184.7083 - accuracy: 0.9238 - precision: 0.9241 - recall: 0.9235 - auc: 0.9792 - val_loss: 0.1701 - val_tp: 757.0000 - val_fp: 46.0000 - val_tn: 757.0000 - val_fn: 46.0000 - val_accuracy: 0.9427 - val_precision: 0.9427 - val_recall: 0.9427 - val_auc: 0.9821
# Epoch 67/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1563 - tp: 2154.9722 - fp: 179.4444 - tn: 2155.6667 - fn: 180.1389 - accuracy: 0.9253 - precision: 0.9255 - recall: 0.9251 - auc: 0.9802 - val_loss: 0.1680 - val_tp: 759.0000 - val_fp: 47.0000 - val_tn: 756.0000 - val_fn: 44.0000 - val_accuracy: 0.9433 - val_precision: 0.9417 - val_recall: 0.9452 - val_auc: 0.9822
# Epoch 68/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1524 - tp: 2161.6111 - fp: 174.2083 - tn: 2160.9028 - fn: 173.5000 - accuracy: 0.9275 - precision: 0.9276 - recall: 0.9274 - auc: 0.9811 - val_loss: 0.1673 - val_tp: 759.0000 - val_fp: 46.0000 - val_tn: 757.0000 - val_fn: 44.0000 - val_accuracy: 0.9440 - val_precision: 0.9429 - val_recall: 0.9452 - val_auc: 0.9826
# Epoch 69/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1482 - tp: 2168.5694 - fp: 167.2639 - tn: 2167.8472 - fn: 166.5417 - accuracy: 0.9301 - precision: 0.9304 - recall: 0.9296 - auc: 0.9821 - val_loss: 0.1673 - val_tp: 761.0000 - val_fp: 45.0000 - val_tn: 758.0000 - val_fn: 42.0000 - val_accuracy: 0.9458 - val_precision: 0.9442 - val_recall: 0.9477 - val_auc: 0.9828
# Epoch 70/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1444 - tp: 2174.1389 - fp: 162.9861 - tn: 2172.1250 - fn: 160.9722 - accuracy: 0.9324 - precision: 0.9325 - recall: 0.9323 - auc: 0.9830 - val_loss: 0.1676 - val_tp: 761.0000 - val_fp: 44.0000 - val_tn: 759.0000 - val_fn: 42.0000 - val_accuracy: 0.9465 - val_precision: 0.9453 - val_recall: 0.9477 - val_auc: 0.9830
# Epoch 71/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1400 - tp: 2177.6806 - fp: 159.2639 - tn: 2175.8472 - fn: 157.4306 - accuracy: 0.9336 - precision: 0.9335 - recall: 0.9338 - auc: 0.9838 - val_loss: 0.1671 - val_tp: 760.0000 - val_fp: 42.0000 - val_tn: 761.0000 - val_fn: 43.0000 - val_accuracy: 0.9471 - val_precision: 0.9476 - val_recall: 0.9465 - val_auc: 0.9833
# Epoch 72/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1365 - tp: 2183.9583 - fp: 152.9444 - tn: 2182.1667 - fn: 151.1528 - accuracy: 0.9360 - precision: 0.9361 - recall: 0.9359 - auc: 0.9842 - val_loss: 0.1667 - val_tp: 760.0000 - val_fp: 42.0000 - val_tn: 761.0000 - val_fn: 43.0000 - val_accuracy: 0.9471 - val_precision: 0.9476 - val_recall: 0.9465 - val_auc: 0.9836
# Epoch 73/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1327 - tp: 2188.5694 - fp: 146.9583 - tn: 2188.1528 - fn: 146.5417 - accuracy: 0.9384 - precision: 0.9390 - recall: 0.9378 - auc: 0.9850 - val_loss: 0.1667 - val_tp: 761.0000 - val_fp: 41.0000 - val_tn: 762.0000 - val_fn: 42.0000 - val_accuracy: 0.9483 - val_precision: 0.9489 - val_recall: 0.9477 - val_auc: 0.9838
# Epoch 74/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1302 - tp: 2195.2500 - fp: 141.1944 - tn: 2193.9167 - fn: 139.8611 - accuracy: 0.9415 - precision: 0.9417 - recall: 0.9412 - auc: 0.9857 - val_loss: 0.1664 - val_tp: 761.0000 - val_fp: 42.0000 - val_tn: 761.0000 - val_fn: 42.0000 - val_accuracy: 0.9477 - val_precision: 0.9477 - val_recall: 0.9477 - val_auc: 0.9840
# Epoch 75/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1271 - tp: 2199.1528 - fp: 141.7222 - tn: 2193.3889 - fn: 135.9583 - accuracy: 0.9421 - precision: 0.9411 - recall: 0.9433 - auc: 0.9863 - val_loss: 0.1673 - val_tp: 761.0000 - val_fp: 42.0000 - val_tn: 761.0000 - val_fn: 42.0000 - val_accuracy: 0.9477 - val_precision: 0.9477 - val_recall: 0.9477 - val_auc: 0.9837
# Epoch 76/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1241 - tp: 2204.3333 - fp: 136.0000 - tn: 2199.1111 - fn: 130.7778 - accuracy: 0.9446 - precision: 0.9438 - recall: 0.9454 - auc: 0.9869 - val_loss: 0.1668 - val_tp: 761.0000 - val_fp: 41.0000 - val_tn: 762.0000 - val_fn: 42.0000 - val_accuracy: 0.9483 - val_precision: 0.9489 - val_recall: 0.9477 - val_auc: 0.9835
# Epoch 77/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1207 - tp: 2208.1528 - fp: 132.0000 - tn: 2203.1111 - fn: 126.9583 - accuracy: 0.9463 - precision: 0.9458 - recall: 0.9469 - auc: 0.9875 - val_loss: 0.1683 - val_tp: 762.0000 - val_fp: 41.0000 - val_tn: 762.0000 - val_fn: 41.0000 - val_accuracy: 0.9489 - val_precision: 0.9489 - val_recall: 0.9489 - val_auc: 0.9835
# Epoch 78/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1170 - tp: 2209.8889 - fp: 124.4444 - tn: 2210.6667 - fn: 125.2222 - accuracy: 0.9479 - precision: 0.9485 - recall: 0.9472 - auc: 0.9881 - val_loss: 0.1684 - val_tp: 763.0000 - val_fp: 40.0000 - val_tn: 763.0000 - val_fn: 40.0000 - val_accuracy: 0.9502 - val_precision: 0.9502 - val_recall: 0.9502 - val_auc: 0.9836
# Epoch 79/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1139 - tp: 2211.1806 - fp: 121.1528 - tn: 2213.9583 - fn: 123.9306 - accuracy: 0.9492 - precision: 0.9499 - recall: 0.9485 - auc: 0.9887 - val_loss: 0.1689 - val_tp: 763.0000 - val_fp: 41.0000 - val_tn: 762.0000 - val_fn: 40.0000 - val_accuracy: 0.9496 - val_precision: 0.9490 - val_recall: 0.9502 - val_auc: 0.9838
# Epoch 80/80
# 71/71 [==============================] - 2s 23ms/step - loss: 0.1101 - tp: 2214.9722 - fp: 119.0000 - tn: 2216.1111 - fn: 120.1389 - accuracy: 0.9503 - precision: 0.9507 - recall: 0.9498 - auc: 0.9894 - val_loss: 0.1706 - val_tp: 763.0000 - val_fp: 41.0000 - val_tn: 762.0000 - val_fn: 40.0000 - val_accuracy: 0.9496 - val_precision: 0.9490 - val_recall: 0.9502 - val_auc: 0.9837
# [[1222   47]
#  [  24   43]]

# %%
# save histories, testing data, histories, and models

import pickle
for fold in range(0,5):
  for model in range(0,5):
    path = '/content/drive/MyDrive/COLAB/saved_models/ensemblemodel_' + str(fold) + '-' + str(model)
    models_byfold[fold][model].save(path)
  
  path = "/content/drive/MyDrive/COLAB/saved_models/X_train_" + str(fold) + ".dat"
  with open(path, "wb") as f:
    pickle.dump(X_train_byfold[fold], f)

  path = "/content/drive/MyDrive/COLAB/saved_models/X_test_" + str(fold) + ".dat"
  with open(path, "wb") as f:
    pickle.dump(X_test_byfold[fold], f)
  
  path = "/content/drive/MyDrive/COLAB/saved_models/Y_test_" + str(fold) + ".dat"
  with open(path, "wb") as f:
    pickle.dump(y_test_byfold[fold], f)
  
  path = "/content/drive/MyDrive/COLAB/saved_models/Y_train_" + str(fold) + ".dat"
  with open(path, "wb") as f:
    pickle.dump(y_train_byfold[fold], f)

with open("/content/drive/MyDrive/COLAB/saved_models/ensemblemodel_histories_byfold.dat", "wb") as f:
  pickle.dump(histories_byfold, f)
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_0-0/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_0-1/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_0-2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_0-3/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_0-4/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_1-0/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_1-1/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_1-2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_1-3/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_1-4/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_2-0/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_2-1/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_2-2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_2-3/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_2-4/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_3-0/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_3-1/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_3-2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_3-3/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_3-4/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_4-0/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_4-1/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_4-2/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_4-3/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/COLAB/saved_models/ensemblemodel_4-4/assets

# %%
# save the models
import pickle as pkl

path  = '/Users/jtollefs/Documents/SOCIOLOGY/github/MGP_circle_detection/ML_training/saved_models/'
file = path+'mlp_models_byfold.pkl'
with open(file, 'wb') as f:
    pkl.dump(pipes_byfold, f)
